# %%
from collections import OrderedDict
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import List
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import OrdinalEncoder
from ktools.modelling.models.pytorch_ffn_model import PytorchFFNModel
from ktools.modelling.Interfaces.i_sklearn_model import IKtoolsModel
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from ktools.fitting.cross_validation_executor import CrossValidationExecutor

# %%
from copy import deepcopy
from ktools.preprocessing.basic_feature_transformers import ConvertObjectToCategorical
from ktools.utils.data_science_pipeline_settings import DataSciencePipelineSettings


train_csv_path = "/Users/yuwei-1/Documents/projects/Kaggle-tools/data/loan_approval/train.csv"
test_csv_path = "/Users/yuwei-1/Documents/projects/Kaggle-tools/data/loan_approval/test.csv"
original_csv_path = "/Users/yuwei-1/Documents/projects/Kaggle-tools/data/loan_approval/original.csv"
target_col_name = "loan_status"

settings = DataSciencePipelineSettings(train_csv_path,
                                        test_csv_path,
                                        target_col_name,
                                        original_csv_path=original_csv_path
                                        )
class OrdinalEncoderTransform:
    @staticmethod
    def transform(original_settings : DataSciencePipelineSettings):
        settings = deepcopy(original_settings)
        enc = OrdinalEncoder()
        settings.combined_df[settings.training_col_names] = enc.fit_transform(settings.combined_df[settings.training_col_names])
        return settings
    
settings = OrdinalEncoderTransform.transform(settings)
train_df, test_df = settings.update()
test_df.drop(columns=[target_col_name], inplace=True)

# %%
train_features = list(test_df.columns)
train_features
# Out:
# ['person_age',
#  'person_income',
#  'person_home_ownership',
#  'person_emp_length',
#  'loan_intent',
#  'loan_grade',
#  'loan_amnt',
#  'loan_int_rate',
#  'loan_percent_income',
#  'cb_person_default_on_file',
#  'cb_person_cred_hist_length',
#  'source']

# %%
# oe = OrdinalEncoder()
# train_df[train_features] = oe.fit_transform(train_df[train_features])

train = train_df[train_df['source'] == 0]
original = train_df[train_df['source'] == 1]
X, y = train.drop(columns=target_col_name), train[[target_col_name]]
Xog, yog = original.drop(columns=target_col_name), original[[target_col_name]]

# %%
cat_sizes = [int(x) + 1 for x in train_df[train_features].max().values]
cat_emb = [5*int(np.sqrt(x)) for x in cat_sizes]
pynn = PytorchFFNModel(len(train_features),
                        output_dim=1,
                        categorical_idcs=list(range(len(train_features))),
                        categorical_sizes=cat_sizes,
                        categorical_embedding=cat_emb,
                        # num_hidden_layers=2,
                        # dim_decay=0.5,
                        metric_callable=roc_auc_score,
                        maximise=True,
                        activation='gelu',
                        last_activation='sigmoid',
                        loss=nn.BCELoss(),
                        epochs=10)

# %%
from ktools.modelling.create_oof_from_model import create_oofs_from_model


kf = StratifiedKFold(10, shuffle=True, random_state=42)
cve = CrossValidationExecutor(pynn,
                              roc_auc_score,
                              kf,
                              verbose=2
                              )

create_oofs_from_model(cve,
                       X, y,
                       test_df,
                       additional_data=[Xog, yog],
                       model_string='pytorch_embedding',
                       directory_path="")
# _ = cve.run(X, y, additional_data=[Xog, yog])
# Out:
# Current learning rate:  0.001
# Loss at epoch 1: 332.7464000582695
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9458923108058239
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 233.8906639404595
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9467565862311162
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 184.68234072998166
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9480979988333472
# here at epoch 2
# Current learning rate:  0.0001
# Loss at epoch 4: 109.34435658808798
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9521627123486626
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 89.88952867779881
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9515148629182987
# Current learning rate:  1e-05
# Loss at epoch 6: 76.86265001725405
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9498786919203343
# Restoring weights at epoch 3, score: 0.9521627123486626
# The CV results of the current fold is 0.9521627123486626
# Current learning rate:  0.001
# Loss at epoch 1: 333.5403817631304
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9379133581743073
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 235.6851298995316
# <function roc_auc_score at 0x16e839000> value for valid set: 0.942498303591624
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 186.1522136107087
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9428313948643469
# here at epoch 2
# Current learning rate:  0.0001
# Loss at epoch 4: 109.00770038366318
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9461963548053
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 90.44583593215793
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9456542184021618
# Current learning rate:  1e-05
# Loss at epoch 6: 77.86375069525093
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9450737491220342
# Restoring weights at epoch 3, score: 0.9461963548053
# The CV results of the current fold is 0.9461963548053
# Current learning rate:  0.001
# Loss at epoch 1: 334.3483046516776
# <function roc_auc_score at 0x16e839000> value for valid set: 0.952485565648028
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 237.08237501606345
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9574486018023595
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 187.04246567748487
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9552941036416234
# Current learning rate:  0.0001
# Loss at epoch 4: 112.16699451953173
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9614149831549625
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 92.520164209418
# <function roc_auc_score at 0x16e839000> value for valid set: 0.959951429149653
# Current learning rate:  1e-05
# Loss at epoch 6: 79.54936445597559
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9584381138319783
# Restoring weights at epoch 3, score: 0.9614149831549625
# The CV results of the current fold is 0.9614149831549625
# Current learning rate:  0.001
# Loss at epoch 1: 334.0031052157283
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9470794395304817
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 235.63489117845893
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9536343614956965
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 185.61199952848256
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9546700634516256
# here at epoch 2
# Current learning rate:  0.0001
# Loss at epoch 4: 111.5532747739926
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9574690777490744
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 91.4025599565357
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9563923048535137
# Current learning rate:  1e-05
# Loss at epoch 6: 78.31897597387433
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9551229152033902
# Restoring weights at epoch 3, score: 0.9574690777490744
# The CV results of the current fold is 0.9574690777490744
# Current learning rate:  0.001
# Loss at epoch 1: 333.7579797580838
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9452637468601564
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 237.02133071795106
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9520712848656563
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 185.6565892715007
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9523148533946024
# here at epoch 2
# Current learning rate:  0.0001
# Loss at epoch 4: 111.46760202385485
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9566564683753765
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 90.9451997615397
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9561026654444589
# Current learning rate:  1e-05
# Loss at epoch 6: 78.16933709196746
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9543072106284449
# Restoring weights at epoch 3, score: 0.9566564683753765
# The CV results of the current fold is 0.9566564683753765
# Current learning rate:  0.001
# Loss at epoch 1: 333.00636480748653
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9404167207442344
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 234.53254996612668
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9475871085429063
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 183.8443468697369
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9426950037090266
# Current learning rate:  0.0001
# Loss at epoch 4: 110.70119498763233
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9459872857188785
# Restoring weights at epoch 1, score: 0.9475871085429063
# The CV results of the current fold is 0.9475871085429063
# Current learning rate:  0.001
# Loss at epoch 1: 333.1469080373645
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9494169743630656
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 236.23870779573917
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9551378055184123
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 186.11295373365283
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9501697341050649
# Current learning rate:  0.0001
# Loss at epoch 4: 109.85631025582552
# <function roc_auc_score at 0x16e839000> value for valid set: 0.958136699359285
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 90.0044033145532
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9573489330743961
# Current learning rate:  1e-05
# Loss at epoch 6: 77.24837622512132
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9569267113019935
# Restoring weights at epoch 3, score: 0.958136699359285
# The CV results of the current fold is 0.958136699359285
# Current learning rate:  0.001
# Loss at epoch 1: 335.00370804965496
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9476735532712661
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 236.1472788155079
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9548027428936122
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 184.97332234866917
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9532188754326701
# Current learning rate:  0.0001
# Loss at epoch 4: 109.98794626630843
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9604842809906137
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 90.32583192270249
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9587670552710449
# Current learning rate:  1e-05
# Loss at epoch 6: 77.55308815464377
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9578092572064064
# Restoring weights at epoch 3, score: 0.9604842809906137
# The CV results of the current fold is 0.9604842809906137
# Current learning rate:  0.001
# Loss at epoch 1: 334.11309388279915
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9435282546856972
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 234.46987867355347
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9489430762654449
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 185.70312437228858
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9454960034196868
# Current learning rate:  0.0001
# Loss at epoch 4: 110.21067790687084
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9535853725041468
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 90.00077242776752
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9528966723542377
# Current learning rate:  1e-05
# Loss at epoch 6: 77.36593120917678
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9524096765705018
# Restoring weights at epoch 3, score: 0.9535853725041468
# The CV results of the current fold is 0.9535853725041468
# Current learning rate:  0.001
# Loss at epoch 1: 332.18614104390144
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9418446066705325
# here at epoch 0
# Current learning rate:  0.001
# Loss at epoch 2: 233.853798776865
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9460977825617407
# here at epoch 1
# Current learning rate:  0.0001
# Loss at epoch 3: 184.71083258278668
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9427416790995461
# Current learning rate:  0.0001
# Loss at epoch 4: 109.60351606458426
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9501818792321897
# here at epoch 3
# Current learning rate:  0.0001
# Loss at epoch 5: 90.2624808754772
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9496514229445265
# Current learning rate:  1e-05
# Loss at epoch 6: 77.71966243069619
# <function roc_auc_score at 0x16e839000> value for valid set: 0.9483732078495624
# Restoring weights at epoch 3, score: 0.9501818792321897
# The CV results of the current fold is 0.9501818792321897
# ####################################################################################################
# OOF prediction score :  0.9541802300558442
# Mean 10-cv results : 0.9543874937062518 +- 0.005018740986684437
# ####################################################################################################
# ((0.9541802300558442, 0.9543874937062518),
#  array([1.44733014e-02, 4.34155157e-03, 2.74836575e-03, ...,
#         9.29104209e-01, 5.04472218e-02, 6.44431449e-04]),
#  array([0.99833505, 0.01191728, 0.80061857, ..., 0.00307522, 0.13684568,
#         0.89071956]),
#  [<ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x3348b2ef0>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x33481f610>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x3471a7af0>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x3348b0a30>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x34716fb20>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x33481f670>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x3471a7bb0>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x3471e7250>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x3471e7d30>,
#   <ktools.modelling.models.pytorch_ffn_model.PytorchFFNModel at 0x3471e7e50>])
