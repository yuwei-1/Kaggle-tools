# %%
import pandas as pd
from pathlib import Path

# %%
comp_data_path = Path("./data/playground-series-s6e4")
train_path = comp_data_path / "train.csv"
test_path = comp_data_path / "test.csv"
original_data_path = comp_data_path / "original.csv"
submission_path = comp_data_path / "sample_submission.csv"

# %%
train_data = pd.read_csv(train_path, index_col="id")
test_data = pd.read_csv(test_path, index_col="id")
original_data = pd.read_csv(original_data_path)

# %%
train_data["Irrigation_Need"].value_counts()

# %%
categorical_cols = train_data.select_dtypes(include=["object", "category"]).columns
numerical_cols = train_data.select_dtypes(include=["number"]).columns

print(f"Number of categorical columns: {len(categorical_cols)}")
print(f"Number of numerical columns: {len(numerical_cols)}")

# %%
train_data[categorical_cols].nunique()

# %%
original_data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import balanced_accuracy_score

# %%
log_model = Pipeline(
    [
        ("scaler", StandardScaler()),
        ("classifier", LogisticRegression(max_iter=1000, random_state=42)),
    ]
)

X = original_data[numerical_cols]
y = LabelEncoder().fit_transform(original_data["Irrigation_Need"])

# %%
log_model.fit(X, y)

# %%
y_pred = log_model.predict(X)

# %%
y_pred

# %%
balanced_acc = balanced_accuracy_score(y, y_pred)
print(f"Balanced Accuracy Score: {balanced_acc:.4f}")
